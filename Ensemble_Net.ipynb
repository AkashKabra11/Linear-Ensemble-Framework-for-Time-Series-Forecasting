# %%
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')

import matplotlib
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

from pylab import rcParams
rcParams['figure.figsize'] = 18, 8


from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, median_absolute_error, mean_squared_log_error
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("train.csv")

# %%
y = df['gt']

# %%
x1 = df['1']
x2 = df['2']
x3 = df['3']
x4 = df['4']
x = pd.concat([x3, x4], axis = 1)

# %%
# define the keras model
model = Sequential()
model.add(Dense(5, input_dim=2, activation='relu'))
model.add(Dense(3, activation='relu'))
model.add(Dense(1, activation='relu'))
# Out:
# WARNING:tensorflow:From /home/akash/.virtualenvs/cvpy3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.compile(loss='mean_absolute_percentage_error', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x, y, epochs=300, batch_size=1)
# Out:
# WARNING:tensorflow:From /home/akash/.virtualenvs/cvpy3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/300
# 90/90 [==============================] - 0s 3ms/step - loss: 32.5906 - acc: 0.0000e+00
# Epoch 2/300
# 90/90 [==============================] - 0s 893us/step - loss: 4.6157 - acc: 0.0000e+00
# Epoch 3/300
# 90/90 [==============================] - 0s 867us/step - loss: 4.4394 - acc: 0.0444
# Epoch 4/300
# 90/90 [==============================] - 0s 921us/step - loss: 4.5417 - acc: 0.0000e+00
# Epoch 5/300
# 90/90 [==============================] - 0s 862us/step - loss: 4.4778 - acc: 0.0000e+00
# Epoch 6/300
# 90/90 [==============================] - 0s 926us/step - loss: 4.3497 - acc: 0.0444
# Epoch 7/300
# 90/90 [==============================] - 0s 864us/step - loss: 4.4823 - acc: 0.0111
# ...

# %%
model.save("Model_LSTM_ARIMA.h5")

# %%
val = pd.read_csv("validate.csv")

# %%
y_val = val['gt']
x_val1 = val['1']
x_val2 = val['2']
x_val3 = val['3']
x_val4 = val['4']
x_val = pd.concat([x_val3, x_val4], axis = 1)

# %%
from keras.models import load_model

model_load = load_model("Model_LSTM_ARIMA.h5")

loss, acc = model_load.evaluate(x_val, y_val, verbose=0)

# %%
y_pred = model_load.predict(x_val)

# %%
plt.plot(y_val)
plt.plot(y_pred)

print(r2_score(y_val , y_pred))
# Out:
# 0.8577711004008984

# %%
plt.plot(y_val)
plt.plot(val['1'])

print(r2_score(y_val , val['1']))
# Out:
# 0.962687922122725

# %%
plt.plot(y_val)
plt.plot(val['2'])

print(r2_score(y_val , val['2']))
# Out:
# 0.8574186424593153

# %%
plt.plot(y_val)
plt.plot(val['3'])

print(r2_score(y_val , val['3']))
# Out:
# 0.8997606304915199

# %%
plt.plot(y_val)
plt.plot(val['4'])

print(r2_score(y_val , val['4']))
# Out:
# 0.7458215923721605
